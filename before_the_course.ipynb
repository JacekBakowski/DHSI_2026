# %% [markdown]
# # Before the Course
#
# Please execute all the cells below carefully to set up your environment.
# This will help us save time and go smoothly through the course :)

# %%
import sys, subprocess, os
REQUIRED = (3, 11)

if sys.version_info < REQUIRED:
    print(f'**** BEWARE **** - Your current Python version is {sys.version_info.major}.{sys.version_info.minor}')
    print(f'_____ Please before the course upgrade to 3.11 _____ ')
else:
    print(f'Your current Python version is: {sys.version_info.major}.{sys.version_info.minor} — This is fine :)')
    print('✓ Python version is OK')
    
expected = os.path.abspath(".venv")
actual = sys.prefix

if actual.startswith(expected):
    print(f"✓ Correct kernel: {actual}")
else:
    print('Please see below for instructions on how to switch to the right kernel')
    print('If you have some problems here, please contact me before the course starts so we can fix it together :)')
# Out:
# Your current Python version is: 3.11 — This is fine :)
# ✓ Python version is OK
# ✓ Correct kernel: /Users/jacek_bakowski/DHSI_2026/.venv

# %% [markdown]
# You should see above something like that:
#
# ✓ Python version is OK
# ✓ Correct kernel: /.....
#
# If it is the case, your setup is probably fine!
#
# If not, please choose manually the correct kernel:
#
# **If you have some you will probably have to do the following:**
#
# **1. Click on the kernel name in the top-right of this notebook**
#
# **2. Click 'Select Another Kernel...'**
#
# **3. Click 'Python Environments...'**
#
# **4. Choose the option whose path contains '.venv' and DHSI.**
#
# **5. Re-run the cell above.**
#
# **6. Please contact me before the course if you have some problems, so we can fix it together**

# %% [markdown]
#  ## Please check that the Spacy module to process English language is properly installed:
# Please run the two cells below. If the previous cell did not display any errors, everything should be fine.
# If after running the second cell you receive a greeting message *Your setup is ready, you can start the course*. that means that everyting is perfect.

# %%
import spacy
! python -m spacy download en_core_web_sm
# Out:
# Resolved 1 package in 4.90s
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)-------------------     0 B/12.21 MiB
# ⠙ Preparing packages... (0/1)------------------- 16.00 KiB/12.21 MiB
# ⠙ Preparing packages... (0/1)------------------- 32.00 KiB/12.21 MiB
# ⠙ Preparing packages... (0/1)------------------- 48.00 KiB/12.21 MiB
# ⠙ Preparing packages... (0/1)------------------- 64.00 KiB/12.21 MiB
# ⠙ Preparing packages... (0/1)------------------- 80.00 KiB/12.21 MiB
# ⠙ Preparing packages... (0/1)------------------- 96.00 KiB/12.21 MiB
# ⠙ Preparing packages... (0/1)------------------- 112.00 KiB/12.21 MiB
# ⠙ Preparing packages... (0/1)------------------- 128.00 KiB/12.21 MiB
# ⠙ Preparing packages... (0/1)------------------- 144.00 KiB/12.21 MiB
# ⠙ Preparing packages... (0/1)------------------- 160.00 KiB/12.21 MiB
# ⠙ Preparing packages... (0/1)------------------- 176.00 KiB/12.21 MiB
# ⠙ Preparing packages... (0/1)------------------- 192.00 KiB/12.21 MiB
# ...

# %%
nlp = spacy.load("en_core_web_sm")
print("OK!!!! -------------->  Spacy ready, model loaded")
print("Your setup is ready, you can start the course :)")
# Out:
# OK!!!! -------------->  Spacy ready, model loaded
# Your setup is ready, you can start the course :)

# %% [markdown]
# ## Troubleshooting Cell (only if you have some problems):

# %%
import sys, os

expected = os.path.abspath(".venv")
actual = sys.prefix

if not actual.startswith(expected):
    raise RuntimeError(
        f"⚠️  WRONG PYTHON KERNEL\n"
        f"This notebook needs the Python from .venv but is currently using:\n"
        f"   {actual}\n\n"
        f"How to fix:\n"
        f"  1. Click on the kernel name in the top-right of this notebook\n"
        f"     (it currently says 'Python {sys.version_info.major}.{sys.version_info.minor}.x').\n"
        f"  2. Click 'Select Another Kernel...'\n"
        f"  3. Click 'Python Environments...'\n"
        f"  4. Choose the option whose path contains '.venv'.\n"
        f"  5. Re-run this cell.\n"
    )

print(f"✓ Correct kernel: {actual}")
# Out:
# ✓ Correct kernel: /Users/jacek_bakowski/DHSI_2026/.venv
